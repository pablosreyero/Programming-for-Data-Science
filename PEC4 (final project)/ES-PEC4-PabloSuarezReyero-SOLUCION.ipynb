# %% [markdown]
# <div style="width: 100%; clear: both;">
#     <div style="float: left; width: 50%;">
#        <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg", align="left">
#     </div>
# </div>
#
# <div style="float: right; width: 50%;">
#     <p style="margin: 0; padding-top: 22px; text-align:right;">22.403 · Programació per a la ciència de dades</p>
#     <p style="margin: 0; text-align:right;">Grau en Ciència de Dades Aplicada</p>
#     <p style="margin: 0; text-align:right; padding-button: 100px;">Estudis d'Informàtica, Multimèdia i Telecomunicació</p>
# </div>
#
# </div>
# <div style="width: 100%; clear: both;">
# <div style="width:100%;">&nbsp;</div>

# %% [markdown]
# Programación para la ciencia de datos - PEC4
# ============================
#
# En este Notebook encontraréis el ejercicio que supone la cuarta y última actividad de evaluación continuada (PEC) de la asignatura. Esta PEC intenta presetaros un pequeño proyecto en el cual debéis resolver diferentes ejercicios, que  engloba muchos de los conceptos cubiertos durante la asignatura.
#
# El objetivo de este ejercicio será desarrollar un **paquete de Python** fuera del entorno de Notebooks, que nos permita resolver el problema dado.
# Trabajaréis en archivos Python planos `.py`. Este tendrá que incluir el correspondiente código organizado lógicamente (separado por módulos, organizados por funcionalidad,...), la documentación del código (*docstrings*) y tests. Además, tendréis que incluir los correspondientes archivos de documentación de alto nivel (`README`) así como los archivos de licencia y dependencias (`requirements.txt`) comentados en la teoría.
#
# Hacer un `setup.py` es opcional, pero si se hace se valorará positivamente de cara a la nota de la práctica y del curso.

# %% [markdown]
# # Enunciado:
#
# La compañía de medios de comunicación Open Broadcast Corporation se está planteando adquirir licencias de emisión de programas de televisión populares con las que espera aumentar significativamente el número de suscriptores. Para poder tomar las decisiones de la mejor manera posible, nos han encargado analizar el contenido de la base de datos *The Movie Database (TMDB)*, que contiene información de más de 159.000 programas de televisión.
# La información de esta base de datos está distribuida en tres ficheros que contienen las siguientes variables:
#
# **TMDB_info.csv**
# - **id**: identificador único de la serie
# - **name**: nombre de la serie
# - **number_of_seasons**: número de temporadas de la serie
# - **number_of_episodes**: número de episodios de la serie
# - **original_language**: idioma original
# - **languages**: idiomas en que está disponible la serie
# - **spoken_languages**: idiomas hablados en la serie
# - **episode_run_time**: tiempo de duración de cada episodio en minutos
# - **vote_count**: número de votos
# - **vote_average**: valor promedio de los votos
# - **popularity**: indicador de popularidad
# - **first_air_date**: fecha de la primera emisión
# - **last_air_date**: fecha de la última emisión
# - **adult**: si el contenido de la serie es para adultos
# - **in_production**: si la serie está en producción
# - **type**: tipo de programa
# - **status**: estado de la serie
#
# **TMDB_overview.csv**
# - **id**: identificador único de la serie
# - **original_name**: nombre de la serie en su idioma original
# - **tagline**: eslogan publicitario
# - **overview**: resumen de la trama
# - **backdrop_path**: ruta del backdrop de la serie en su página web
# - **homepage**: página web de la serie
# - **poster_path**: ruta del poster de la serie en su página web
#
# **TMDB_distribution.csv**
# - **id**: identificador único de la serie
# - **genres**: géneros de la serie
# - **created_by**: autores de la serie
# - **networks**: plataformas de emisión
# - **production_companies**: empresas productoras
# - **origin_country**: países de origen
# - **production_countries**: países de producción
#
# Estos tres ficheros se encuentran en la carpeta comprimida **TMDB.zip**.

# %% [markdown]
# # Presentación de los resultados:
#
# Para hacer la entrega más fácil y homogénea os pedimos que organicéis el código de tal manera que **desde el fichero principal retorne todas las respuestas que se os pida en la PEC** haciendo uso de funciones que tendréis que definir en módulos.  Para eso, en cada ejercicio, os indicaremos el formato que tiene que tener cada respuesta, de tal manera que ejecutando `main.py` se vaya respondiendo a toda la PEC. Por defecto, `main.py` debe ejecutar todas las funciones de la PEC mostrando cómo funcionan pero también debe permitir ejecutarlas una a una si se desea. Debéis documentarlo todo muy bien en el README para que se pueda ejecutar sin problema. Os recordamos que en el README también tenéis que indicar como ejecutar los test y comprobar la cobertura de éstos.

# %% [markdown]
# ## Ejercicio 1: Descompresión y lectura de ficheros.
#
#
# #### Ejercicio 1.1.
#
# Implementad una función que descomprima ficheros en formato zip y tar.gz. La función recibirá como inputs la ruta con el nombre del fichero que se quiere descomprimir. La función detectará automáticamente si el fichero está comprimido en zip o en tar.gz y mostrará un mensaje de error cuando el fichero sea de otro tipo. Utilizad esta función para descomprimir el fichero TMDB.zip.
#
# **Referencias**
#
# - https://stackoverflow.com/questions/541390/extracting-extension-from-filename-in-python
#
# #### Ejercicio 1.2.
#
# Implementad una función que lea los csv y los integre en un único dataframe utilizando como clave la columna "id" utilizando la librería **pandas**. Obtened el tiempo de procesamiento.
#
# **Referencias**
#
# - https://saturncloud.io/blog/pandas-how-to-concatenate-dataframes-with-different-columns/#:~:text=To%20concatenate%20dataframes%20with%20different%20columns%2C%20we%20use%20the%20concat,new%20dataframe%20that%20combines%20them.&text=Let's%20break%20down%20each%20argument,list%20of%20dataframes%20to%20concatenate.
#
# #### Ejercicio 1.3.
#
# Implementad una función que lea los csv y los integre en un único diccionario utilizando como clave la columna "id" utilizando la librería **csv**. Obtened el tiempo de procesamiento.
#
# **Referencias**
#
# - https://stackoverflow.com/questions/63230336/taking-a-column-from-a-csv-file-and-putting-it-into-a-list-in-python
#
# - https://www.geeksforgeeks.org/merge-two-pandas-dataframes-on-certain-columns/
#
# #### Ejercicio 1.4.
#
# ¿Qué diferencias se observan en la lectura de los ficheros siguiendo ambos métodos? ¿Si los ficheros tuvieran un tamaño de 10GB qué método sería más rápido? Justificad la respuesta.
#
# **Observaciones**
#
# *Se observa claramente, como al programa le toma más tiempo leer los archivos csv, con la librería csv, que con la librería pandas. Observando los tiempos obtenidos, podemos ver como la lectura y conversión de los archivos CSVs en un solo dataframe usando la librería pandas, solamente toma 1.12 segundos. No obstante, si leemos los tres CSVs, y los convertimos a un solo diccionario con ayuda de la librería csv, el tiempo transcurrido es 3.35 veces mayor, pues se obtiene una marca de 3.75 segundos.*
#
# *En el caso de la librería csv, hemos tenido que abrir el arhivo con `with ...` y especificar algunos parámetros para leer el csv correctamente, cosa que no hemos tenido que hacer con la librería de pandas, pues simplemente hemos implementado: `df_i = pd.read_csv(·)`
# Observando estos resultados y mirando el código, podemos darnos cuenta de que tiene bastante sentido el resultado que hemos obtenido, ya que en el caso de pandas, simplemente estamos leyendo el archivo csv y cargamos los datos en un dataframe de pandas. Mientras que con el método basado en la librería de csv, estamos abriendo el archivo en modo lectura y estamos creando un objeto 'reader' que contiene todas las lineas del csv, sobre el cual, posteriormente iteramos para ir creando el nuevo diccionario con sus respectivas claves para cada ID. Pero el problema de csv, viene cuando son archivos muy grandes, como pasa en nuestro caso, donde se puede ver como pandas trabaja más eficientemente y mejor que csv, cuando hay archivos grandes.*
#
# *Respecto a la pregunta, ¿Si los ficheros tuvieran un tamaño de 10GB qué método sería más rápido?* Podemos decir, que después de haber investigado un poco sobre el tema, nos hemos topado con un enlace a StackOverflow (al final de la respuesta), donde se muestra un estudio de la rápidez entre pandas y csv. En dicho estudio puede verse como la librería csv es mucho más rápida para archivos con menos de 1000 filas, mientras que pandas resulta ser más rápida para archivos grandes. Así que en base a ese estudio, diríamos que pandas sería mejor, en caso de que tuviésemos archivos de 10GB. Aunque gracias a este estudio, también comprobamos porque nosotros obtenemos un mayor tiempo con csv que con pandas. Esto se debe, a que cada uno de los csvs tienen 162138 filas, es decir, 100 veces más que el límite de 1000 filas mencionado antes, por lo que esto, explica la rápidez de pandas frente a csv.
#
# No obstante, a parte del estudio mencionado antes, podemos poner de relieve, algunas características de pandas frente a las de la libreria csv, que también justifican la anterior respuesta. Por ejemplo, la librería pandas, implementa optimizaciones de manera interna, y hace uso de extensiones de bajo nivel, a fin de realizar operaciones eficientes en memoria, cosa que no hace csv.
#
# **Referencias**
#
# Fuente, utilizada para responder a la última parte de esta pregunta:
# (fuente: https://www.learnenough.com/blog/how-to-import-Pandas-in-python#The%20benefits%20of%20learning%20Pandas%20library)
#
# (Enlace al estudio de un usuario en StackOverFLow: https://stackoverflow.com/questions/62139040/pythons-csv-module-vs-pandas)
#
#
#
# ### Ejercicio 2: Procesamiento de datos.
#
#
# #### Ejercicio 2.1.
#
# Añadid una variable air_days al dataframe que consista en el número de días que una serie ha estado en emisión. Mostrad por pantalla los 10 registros del dataset que más días han estado en emisión.
#
# **Referencias**
#
# - https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-pandas-dataframe
# - https://pynative.com/python-difference-between-two-dates/
# - https://stackoverflow.com/questions/13021654/get-column-index-from-column-name-in-python-pandas
# - https://ioflood.com/blog/python-get-current-date/#:~:text=To%20get%20the%20current%20date%20in%20Python%2C%20you%20can%20use,%2DMM%2DDD'%20format.&text=In%20this%20example%2C%20we%20first,class%20from%20the%20datetime%20module.
# - https://www.geeksforgeeks.org/sort-rows-or-columns-in-pandas-dataframe-based-on-values/
# - https://www.youtube.com/watch?v=F-rbHdHV_RU
#
# Para los registros que tenían vacíos `last_air_date` pero no `first_air_date` se ha intentado calcular los días que han pasado, respecto al mismo día que se ejecuta el script, pero no pude, porque el uso de la función `datetime.today`, me daba error, por lo tanto he terminado dejando el campo `air_days = -300000`, para los registros con `last_air_date = ""`. Luego, para aquellos registros que tenían ambos registros vacíos, i.e., `last_air_date = ""` y `first_air_date = ""` el campo `air_days` se ha dejado también como antes, `air_days = -300000`. Por último, los registros que tenían el campo `first_air_date = ""`, pero no el otro, también se ha optado por dejar el campo igual que en los otros dos casos `air_days = -300000` vacío. Por lo tanto, se ha poblado la variable `air_days` en los registros que tienen tanto `last_air_date` como `first_air_date` con una fecha válida.
#
# Al realizar este ejercicio, nos hemos dado cuenta de que a la hora de hacer la cuenta, obteníamos números negativos, esto se debe a que había registros con las fechas de `first_air_date` y `last_air_date` cambiadas. Es por esta razón, por la cual, en el código se compreuba si la resta es negativa, si esto es así entonces los dos valores se intercambian, y se toma el valor absoluto de la resta computada anteriormente, para no tener que computar de nuevo la resta, ya que es el mismo resultado, pero con un menos delante, de ahí el uso `abs(·)`. Al haber identificado este error, para el resto de ejercicios que requieran datos relacionados con las fechas, se usará el nuevo dataframe devuelto en el main, con el nombre de `df_air_days`. Nótese como el dataframe devuelto en el main bajo el nombre de `df_final` se corresponde con el dataframe ordenado de manera ascendente, según los valores de `air_days`, para mostrar los 10 primeros registros del dataframe `df_air_days` con los números de `air_days` más altos.
#
# Para el resto de ejercicios que no requieran de ninguna fecha se seguirá usando el dataframe obtenido en el ejercicio **1.2**, i.e., `df_eje1`
#
# #### Ejercicio 2.2.
#
# Cread un diccionario ordenado cuya clave será el nombre de la serie (name) y cuyo valor será la dirección web completa de su poster (homepage y poster_path). En caso de que homepage o poster_path tengan el valor NaN o "", el valor será el string “NOT AVAILABLE”. Mostrad por pantalla los primeros 5 registros del diccionario.
#
# **Explicación de la solución del ejercicio 2.2**
#
# Entiendo que con el término ordenado, se refiere a respetar el orden de las filas en el *dataframe* original.
#
# Pasando al ámbito de la implementación, he podido ver como al crear el diccionario, había registros con el mismo nombre, e.g., Euphoria. Lo que hecho ha sido añadir a las claves, una lista con cada una de las direcciones web completas, asociadas al nombre de esa serie (en caso de que los dos campos homepage y poster_path estuviesen poblados) en caso contrario, he puesto la lista con las direcciones de los dos campos poblados, y aquel registro que no tuviese los dos o ninguno, he añadido a la lista: 'NOT AVAILABLE' tal y como se pide en el enunciado.
#
# **Referencias**
#
# - https://www.geeksforgeeks.org/python-get-first-n-keyvalue-pairs-in-given-dictionary/
# - https://stackoverflow.com/questions/944700/how-to-check-for-nan-values
#
#
# ### Ejercicio 3: Filtrado de datos.
#
#
# #### Ejercicio 3.1.
#
# Obtened y mostrad por pantalla los nombres de las series cuyo idioma original (original_language) sea el inglés y en cuyo resumen (overview) aparezcan las palabras “mystery” o “crime”, sin tener en cuenta mayúsculas ni minúsculas.
#
# La primera parte de la primera implementación realizada para este ejercicio era:
#
#     `palabras = ['mistery', 'crime']
#     pauta1 = re.compile('|'.join(palabras), flags=re.IGNORECASE)
#
#     ahora hacemos los mismo pero con el idioma
#     idioma = 'en'
#     pauta2 = re.compile('|'.join(idioma), flags=re.IGNORECASE)
#
#     palabras_bool = df_eje1['overview'].apply(lambda x: bool(pauta1.search(x)))
#     idiomas_bool = df_eje1['original_language'].apply(lambda x: bool(pauta2.search(x)))
#
#     print(f"El tamaño de la lista palabras_bool es: {len(palabras_bool)}")
#     print(f"El tamaño de la lista idiomas_bool es: {len(idiomas_bool)}")`
#
# Luego tenía pensado iterar sobre las dos listas con zip, para comprobar si los valores en la mimsa posición erán True o False y si los dos valores en la i-ésima posición coincidian, entonces adjuntar en una lista, el nombre de la serie que estaría en la misma posición i-ésima en el dataframe.
#
# Pero me daba error, porque había registros, que tenían espacios en blanco (float) en la columna `overview` por lo tanto no se podía comprobar la ocurrencia de un string en una variable de tipo float, por ello tuvimos que cambiar la implementación. En el caso del campo `original_languages` no observamos el mismo problema, ya que todos los registros tenían un valor de tipo `str`.
#
# Entiendo que a lo mejor, la implementación de arriba sería menos costosa computacionalmente hablando y en términos de tiempo de ejecución. Pero considero que la implementación final del código, a pesar de que pueda ser más larga, creo que puede ser más segura, ya que estamos iterando fila por fila en el dataframe, y nos aseguramos estar cogiendo todo lo necesario para crear la lista final de nombres correctamente, ya que en esa misma fila estaría el nombre de la serie que deberíamos o no de coger.
#
#
# **Referencias**
#
# - https://stackoverflow.com/questions/53300901/pandas-searching-for-terms-irrespective-of-upper-or-lower-case-of-the-search
#
# - https://stackoverflow.com/questions/4843173/how-to-check-if-type-of-a-variable-is-string
#
# #### Ejercicio 3.2.
#
# Obtened una lista de las series que han empezado en 2023 y han sido canceladas. Mostrad por pantalla los primeros 20 elementos de esta lista.
#
# **Referencias**
#
# En este ejercicio no hay referencias porque la única parte más tediosa, era la parte de las expresiones regulares, pero como lo hemos dado en teoría, ningún problema al respecto.
# Además, para este ejercicio, he tenido en cuenta dos formatos de fecha. El primer formato: yyyxmmxdd , donde x es el separador, e.g., "-" o "/" y el segundo formato: ddxmmxyyyy, donde de nuevo x denota el separador, que puede ser e.g., "-" o "/"
#
# Cabe destacar además, que cuando se comprueba el tipo de valor dentro de los registros, esto se hace para comprobar que la celda no esté vacía, ya que en dicho caso, no sería una variable "str" vacía, sino una variable de tipo "float" vacía. Por lo tanto, así se evita que si la celda esté vacía, se intente procesar con funciones que esperan una variable de tipo "str" un valor vacío de tipo "float".
#
# Como ya comentamos en el ejercicio 2.1, en los ejercicios que requieran de las columnas `first_air_date`, `last_air_date` o `air_days`, haremos uso del dataframe obtenido en el ejercicio 2.1, i.e., `df_air_days` y es lo que hemos hecho justamente en este ejercicio.
#
# #### Ejercicio 3.3.
#
# Obtened un dataframe con los nombres, los nombres originales, las plataformas de emisión y las empresas productoras de todas las series cuyo idioma (variable languages) sea el japonés y mostrar los primeros 20 registros por pantalla. Nota: tened en cuenta que consideramos series en japonés también aquellas que tengan idiomas adicionales, por ejemplo, un registro con idioma “en, ja, ko” se incluiría.
#
# **Referencias**
#
# En este ejercicio tampoco hay referencias, ya que se ha conseguido resolver solamente con conocimientos previos y los adquiridos en la asignatura.
#
#
# ### Ejercicio 4: Análisis gráfico.
#
#
# #### Ejercicio 4.1.
#
# Mostrad en un gráfico de barras el número de series por año de inicio.
#
# **Referencias**
#
# En este ejercicio no se han consultado fuentes externas.
#
# **Aclaración:**
#
# Para resolver este ejercicio, hemos impuesto un filtro. A la hora de representar el número de series por año, nos hemos dado cuenta de que había series desde el 1917, hasta el 2029. Como es obvio, es técnicamente imposible que la primera fecha de emisión fuese en 2029, a no ser que esta sea una fecha especulativa y que la serie esté en proceso de desarrollo. Por ello, y debido a la duda, se ha decidido representar solamente hasta el 2023. Luego, como fecha inicial, en el gráfico aparece el año 1917, lo que nos ha llevado al dataset, y en el único registro con ese año de emisión, uno puede ver que el nombre es: *B-Movies: Las obras maestras del cine cutre*. Tras buscar en internet, nos hemos dado cuenta de que esa no es la fecha de emisión correcta de la serie/documental. Este mismo error se ha observado en el único registro con el año 1921. Tras esta búsqueda nos hemos dado cuenta que podemos incluir las series emitidas a partir del 1936, ya que el primer registro se corresponde con el programa "Starlight" de la BBC, cuya primera fecha de emisión mostrada en el dataset, coincide con la oficial que uno puede consultar en internet, y que se puede ver en la siguiente página web: <https://www.google.com/search?q=starlight+bbc+program+first+air+date&oq=starlight+bbc+program+first+air+date&gs_lcrp=EgZjaHJvbWUyCQgAEEUYORigATIHCAEQIRigATIHCAIQIRifBdIBCDU5NzRqMGo3qAIAsAIA&sourceid=chrome&ie=UTF-8>
#
# Por lo tanto, para la construcción de la gráfica, se han tenido en cuenta las series con la primera fecha de emsisión desde el 1936, hasta el 2023.
#
# Nótese además, que tal y como ya se comentó en el ejercicio 2.1, en los ejercicios que se requiera de las columnas `first_air_date`, `last_air_date` o `air_days`, se hará uso del dataframe obtenido en el ejercicio 2.1, i.e., `df_air_days` y esto es lo que se ha hecho justamente en este ejercicio.
#
# Se adjunta a continuación el gráfico final que se ha obtenido:
#
# ![numero_de_series_por_anioEmision.png](attachment:b4d0bf33-1d66-4601-a9fd-39c4d6dc2dab.png)
#
# Estudiando el gráfico de arriba, podemos ver claramente un comportamiento exponencial en cuanto a número de emisiones por año desde el 1936, hasta el 2023. No obstante en 2023 se observa un pequeño decrecimiento, aunque esto tiene sentido en caso de que este *dataset* se terminase de construir a lo largo del 2023.
# #### Ejercicio 4.2.
#
# Construid un gráfico de líneas que muestre el número de series de cada categoría de la variable “type” producidas en cada década desde 1940. ¿Qué cambios de tendencia se observan?
#
# **Referencias**
#
# - https://www.statology.org/pandas-groupby-plot/
#
# Cabe destacar que para la solución de este ejercicio se han tenido en cuenta varias implementaciones, pero la implementación final es la única que me ha funcionado. Esta implementación toma más tiempo del deseado en crear el nuevo dataframe para luego poder agrupar las columnas y poder representar los valores. No obstante, tiene lógica que al programa le tome tiempo, ya que son 162139 registros, de los cuales, la mayoría tienen una año de comienzo de emisión más tarde que el año 1940, aunque esto no quita que la implementación no sea la más óptima, y que mi código sea muy mejorable.
#
# Un pequeño detalle, es que a lo largo de esta PEC, se hace referencia a cada uno de los registros del dataset con la palabra "serie", a pesar de que los registros se correspondan con películas, informativos/telediarios o incluso documentales. Esto simplemente se ha hecho por comodidad.
#
# Dicho esto, a continuación se va a explicar la tendencia que se observa en la figura/representación que hemos obtenido:
#
# ![numero_series_por_decada.png](attachment:70437de7-7e16-4121-852a-624afd16015f.png)
#
# En la figura de arriba, puede verse claramente, como la mayoría de emisiones son de tipo "Scripted" llegando casi a las 35000 series en la decada del 2010. De hecho, de manera generalizada, el resto de emisiones también experimentan su máximo en la década del 2010. No obstante, el comportamiento que se observa en los programas de tipo "scripted" es de tipo exponencial, y analizando el porque de esto, uno se encuentra con que los programas de tipo "scripted" engloban las series de televisión, películas, y otros programas previamente estructurados y planificados con guiones conocidos, por lo tanto, es normal que se observe un crecimiento tan acentuado. No obstante, al ser el tipo de emisión más común, en 2010, después de alcanzar su pico, este tipo de emisión empieza a decrecer notablemente. La razón más lógica que le encuentro a esta caída, es que en 2008 hubo una crisis financiera global, y puede que fuese en los años del 2009-20010 cuando se implantaron los mayores recortes en el mundo audiovisual, pues se observa en la misma decada, una caída para todas las emisiones registradas en el dataset.
#
# Tras las emisiones de tipo "Scripted" vemos como son los documentales los que más emisiones empiezan a tener a partir de la década de los 2000, no obstante, es en la misma década dónde todos los tipos de emisiones experimentan su pico, cuando estas empeizan a reducirse. El único tipo de emisión que parece ser temporalmente invariante, son las emisiones de noticias, aunque esto tiene sentido, ya que la mayoría de cadenas no han aumentado el número de telediarios/informativos y todas las cadenas mundiales parecen mantener el mismo número de noticieros. Además podemos confirmar como los *realities* parecen ser famosos mundialmente, pue se posicionan en el 4º) puesto en cuanto a número de emisiones máximas.
#
# #### Ejercicio 4.3.
#
# Obtened el número de series por género y mostrad el porcentaje respecto al total en un gráfico circular. Los géneros que representen menos del 1% del total se incluirán en la categoría "Other". Tened en cuenta que una serie que tenga más de un género deberá incluirse en todas las categorías en que esté clasificada y que las series con el campo "genres" vacío no se incluyen.
#
# **Referencias**
#
# - https://www.geeksforgeeks.org/plot-a-pie-chart-in-python-using-matplotlib/
# - https://www.geeksforgeeks.org/applying-lambda-functions-to-pandas-dataframe/
#
# En este ejercicio, la solución planteada es completamente diferente al resto, ya que me he dado cuenta de que mis implementaciones anteriores son demasiado lentas. Por eso en esta implementación me he metido de lleno a revisar y a entender como aplicar las funciones lambda. Definitivamente, este es el ejercicio que más tiempo me ha llevado, porque a pesar de que mi enfoque e implementación inicial funcionaban, esta última tardaba mucho, ya que accedía con bucles a todo y realizaba implemenentaciones de muy bajo nivel (en la carrera programaba en C y C++, por lo tanto hay muchas funciones de Python que para mí son nuevas) por lo tanto, tuve que cambiar el enfoque.
#
# Nótese además, que en la solución propuesta se ha optado por eliminar las celdas vacías, por lo que estas no computan dentro del número de registros totales.
#
# El resultado obtenido en este ejercicio es el siguiente:
#
# ![pie_chart-ej43.png](attachment:b8dc2700-efa5-4a6e-ac97-3001fb4401d2.png)
#
# Como puede verse por el resultado de arriba, el protagonista de la carta, es el género dramático, cubriendo un 22.8 % de la oferta audiovisual total (sin contemplar los registros sin género) Seguidamente encontramos las comedias con un 15.9 % de la "tarta", y en tercera posición encontramos los documentales con un 14,7 % del total. Resulta curioso ver como el género de crimen o el de acción y aventura no llegan a sumar ni la mitad del género dramático. Por último, podemos ver como el resto de géneros que representan menos del 1% de la oferta total están catalogados como 'others'.
#
# ### Ejercicio 5: Conclusiones.
#
# Hacer el setup.py (esta frase la he puesto yo)
#
# Redactad un breve informe que recopile las conclusiones obtenidas en el análisis realizado.
#
# Se ha podido comprobar, como los 3 *datasets* que se han procesado son bastante extensos en cuanto a número de registros. No obstante, esto no ha sido un problema para realizar las tareas que se nos han pedido en cada uno de los ejercicios de esta última PEC de la asignatura. Aunque observando todos los ejercicios, puedo decir con seguridad que el que más me ha hecho aprender ha sido el último (4.3), ya que en dicho ejercicio me he dado cuenta de que no podía seguir implementando código de la manera en la que lo estaba haciendo, obviando todas las facilidades y funciones que Python ofrece, por lo tanto, me puse a repasar bien las funciones lambda y como combinarlas con los *list comprehension* y me puse manos a la obra.
#
#
# Creo que ha sido un proyecto muy interesante en el que no solo hemos puesto en práctica los conocimientos que hemos aprendido en la teoría, sino que nos ha requerido pensar un poco `out-of-the-box` para realizar algunas tareas como los tests o la organización de las funciones diseñadas en archivos separados, y estas son tareas que tendremos que realizar de manera automática de cara a un futuro puesto de trabajo. Por ello creo que es importante destacar, la pincelada realista que tiene esta PEC, porque este tipo de prácticas (organización del código, despliegue de tests, documentación, etc) a mi juicio, son básicas, pero muy importantes, porque permite al resto de personas comprender el código que has desarrollado, y creo que de nada sirve tener una idea brillante, o un código brillante, si uno no es capaz de transmitirlo o explicarlo correctamente. Además, creo que esto último es extrapolable para todo en la vida.
#
# ### Tests
#
# Hace falta notar, que se ha comentado el test de la función 4.2, ya que tardaba mucho en ejecutarse, pero funciona correctamente. Todos los archivos de los tests y la cobertura, pueden consultarse en las carpetas `informes` y `htmlcov`.
# A continuación se muestran los resultados de los tests:
#
# ![467D269D-DC28-4EFE-8A13-29D21FBDA4EB.jpeg](attachment:f0716ad9-eaa2-4159-90f7-a122fad1276a.jpeg)
#
# **COBERTURA**:
#
# Como se puede observar, la cobertura es bastante buena:
#
# ![FC095C81-7653-444A-B5CE-1410F75DCE9E.jpeg](attachment:c4e0d761-07d5-44f0-a087-86fe9e257d8a.jpeg)
#
# Véase también la cobertura en el fichero index.html
#
# <!DOCTYPE html>
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <title>Coverage report</title>
#     <link rel="icon" sizes="32x32" href="favicon_32.png">
#     <link rel="stylesheet" href="style.css" type="text/css">
#     <script type="text/javascript" src="coverage_html.js" defer></script>
# </head>
# <body class="indexfile">
# <header>
#     <div class="content">
#         <h1>Coverage report:
#             <span class="pc_cov">91%</span>
#         </h1>
#         <aside id="help_panel_wrapper">
#             <input id="help_panel_state" type="checkbox">
#             <label for="help_panel_state">
#                 <img id="keyboard_icon" src="keybd_closed.png" alt="Show/hide keyboard shortcuts" />
#             </label>
#             <div id="help_panel">
#                 <p class="legend">Shortcuts on this page</p>
#                 <div class="keyhelp">
#                     <p>
#                         <kbd>n</kbd>
#                         <kbd>s</kbd>
#                         <kbd>m</kbd>
#                         <kbd>x</kbd>
#                         <kbd>c</kbd>
#                         &nbsp; change column sorting
#                     </p>
#                     <p>
#                         <kbd>[</kbd>
#                         <kbd>]</kbd>
#                         &nbsp; prev/next file
#                     </p>
#                     <p>
#                         <kbd>?</kbd> &nbsp; show/hide this help
#                     </p>
#                 </div>
#             </div>
#         </aside>
#         <form id="filter_container">
#             <input id="filter" type="text" value="" placeholder="filter..." />
#         </form>
#         <p class="text">
#             <a class="nav" href="https://coverage.readthedocs.io/en/7.4.0">coverage.py v7.4.0</a>,
#             created at 2024-01-23 23:33 +0100
#         </p>
#     </div>
# </header>
# <main id="index">
#     <table class="index" data-sortable>
#         <thead>
#             <tr class="tablehead" title="Click to sort">
#                 <th class="name left" aria-sort="none" data-shortcut="n">Module</th>
#                 <th aria-sort="none" data-default-sort-order="descending" data-shortcut="s">statements</th>
#                 <th aria-sort="none" data-default-sort-order="descending" data-shortcut="m">missing</th>
#                 <th aria-sort="none" data-default-sort-order="descending" data-shortcut="x">excluded</th>
#                 <th class="right" aria-sort="none" data-shortcut="c">coverage</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr class="file">
#                 <td class="name left"><a href="analisis_grafico_py.html">analisis_grafico.py</a></td>
#                 <td>59</td>
#                 <td>20</td>
#                 <td>0</td>
#                 <td class="right" data-ratio="39 59">66%</td>
#             </tr>
#             <tr class="file">
#                 <td class="name left"><a href="descomp_lectura_py.html">descomp_lectura.py</a></td>
#                 <td>63</td>
#                 <td>7</td>
#                 <td>0</td>
#                 <td class="right" data-ratio="56 63">89%</td>
#             </tr>
#             <tr class="file">
#                 <td class="name left"><a href="filtrado_datos_py.html">filtrado_datos.py</a></td>
#                 <td>64</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td class="right" data-ratio="64 64">100%</td>
#             </tr>
#             <tr class="file">
#                 <td class="name left"><a href="procesado_datos_py.html">procesado_datos.py</a></td>
#                 <td>41</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td class="right" data-ratio="41 41">100%</td>
#             </tr>
#             <tr class="file">
#                 <td class="name left"><a href="testing_imports_py.html">testing_imports.py</a></td>
#                 <td>4</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td class="right" data-ratio="4 4">100%</td>
#             </tr>
#             <tr class="file">
#                 <td class="name left"><a href="d_a44f0ac069e85531___init___py.html">tests/__init__.py</a></td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td>0</td>
#                 <td class="right" data-ratio="0 0">100%</td>
#             </tr>
#             <tr class="file">
#                 <td class="name left"><a href="d_a44f0ac069e85531_test_codes_py.html">tests/test_codes.py</a></td>
#                 <td>152</td>
#                 <td>7</td>
#                 <td>0</td>
#                 <td class="right" data-ratio="145 152">95%</td>
#             </tr>
#         </tbody>
#         <tfoot>
#             <tr class="total">
#                 <td class="name left">Total</td>
#                 <td>383</td>
#                 <td>34</td>
#                 <td>0</td>
#                 <td class="right" data-ratio="349 383">91%</td>
#             </tr>
#         </tfoot>
#     </table>
#     <p id="no_rows">
#         No items found using the specified filter.
#     </p>
# </main>
# <footer>
#     <div class="content">
#         <p>
#             <a class="nav" href="https://coverage.readthedocs.io/en/7.4.0">coverage.py v7.4.0</a>,
#             created at 2024-01-23 23:33 +0100
#         </p>
#     </div>
#     <aside class="hidden">
#         <a id="prevFileLink" class="nav" href="d_a44f0ac069e85531_test_codes_py.html"/>
#         <a id="nextFileLink" class="nav" href="analisis_grafico_py.html"/>
#         <button type="button" class="button_prev_file" data-shortcut="["/>
#         <button type="button" class="button_next_file" data-shortcut="]"/>
#         <button type="button" class="button_show_hide_help" data-shortcut="?"/>
#     </aside>
# </footer>
# </body>
# </html>

# %% [markdown]
# ## Criterios de corrección
#
# Esta PEC se valorará siguiendo los siguientes criterios:
#
# * **Funcionalidad** (6 puntos): Se valorará que el código implemente todo lo que se pide.
#     * Ejercicio 1 (1.5 puntos)
#     * Ejercicio 2 (1 punto)
#     * Ejercicio 3 (1.5 puntos)
#     * Ejercicio 4 (1.5 puntos)
#     * Ejercicio 5 (0.5 puntos)
#
# * **Documentación** (0.5 puntos):  Todas las funciones de los ejercicios de esta PEC tendrán que estar debidamente documentadas utilizando docstrings (en el formato que prefiráis).
# * **Modularidad** (0.5 puntos): Se valorará la modularidad del código (tanto la organización del código en módulos como la creación de funciones).
# * **Estilo** (0.5 puntos): El código tiene que seguir la guía de estilo de Python (PEP8), exceptuando los casos donde hacerlo complique la legibilidad del código.
# * **Tests** (1.5 puntos): El código tiene que contener una o diversas *suites* de tests que permitan comprobar que el código funciona correctamente, con un mínimo del 50% de cobertura.
# * **Requeriments** (0.5 puntos): Tenéis que incluir un fichero de *requirements* que contenga la lista de librerías necesarias para ejecutar el código.
# * **README** y **licencia** (0.5 puntos): Tenéis que añadir también un fichero README, que presente el proyecto y explique cómo ejecutarlo, así como la inclusión de la licencia bajo la que se distribuye el código (podéis escoger la que queráis).

# %% [markdown]
# ### Importante
#
# **Nota 1**: De la misma manera que en las PECs anteriores, los criterios transversales se valorarán de manera proporcional a la parte de funcionalidad implementada.
#
# Por ejemplo, si el código sólo implementa la mitad de la PEC y la documentación está perfecta la puntuación correspondiente a documentación será de 0.25.
#
# **Nota 2**: Es imprescindible que el paquete que libréis se ejecute correctamente en la máquina virtual y que el fichero de REAMDE explique claramente cómo ejecutar el código para generar los resultados pedidos. Además en el README tiene que explicarse también cómo se ejecutarán los test y cómo se comprueba su cobertura.
#
# **Nota 3**: Entregad el paquete como un único archivo .zip que contenga sólo el código en el Registro de Evaluación Continua. **El código de Python tendrá que estar escrito en ficheros planos de Python.**
